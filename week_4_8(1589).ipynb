# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51589/CompetativeProgramming-/blob/main/week_4_8(1589).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False


class Trie:
    def __init__(self):
        self.root = TrieNode()

    # Insert contact
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end = True

    # Search complete word
    def search(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return node.is_end

    # Check prefix
    def starts_with(self, prefix):
        node = self.root
        for char in prefix:
            if char not in node.children:
                return False
            node = node.children[char]
        return True


# -------- Main Program --------

n = int(input("Enter number of contacts: "))
trie = Trie()

for _ in range(n):
    name = input("Enter contact name: ")
    trie.insert(name)

print('Contact "Anil" found →', trie.search("Anil"))
print('Contact "Anand" not found →', trie.search("Anand"))
print('Prefix "Ani" exists →', trie.starts_with("Ani"))
print('Prefix "Bal" exists →', trie.starts_with("Bal"))
# Out:
# Enter number of contacts: 5
# Enter contact name: anil
# Enter contact name: anitha
# Enter contact name: anirudh
# Enter contact name: abhi
# Enter contact name: pranay
# Contact "Anil" found → False
# Contact "Anand" not found → False
# Prefix "Ani" exists → False
# Prefix "Bal" exists → False

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False


class Trie:
    def __init__(self):
        self.root = TrieNode()

    # Insert Operation
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end = True

    # Search Complete Course Code
    def search(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return node.is_end

    # Prefix Query
    def starts_with(self, prefix):
        node = self.root
        for char in prefix:
            if char not in node.children:
                return False
            node = node.children[char]
        return True


# -------- MAIN PROGRAM --------

n = int(input("Enter number of course codes: "))
trie = Trie()

print("Enter course codes:")
for _ in range(n):
    code = input()
    trie.insert(code)

# Example Operations
print('Course code "CS101" found →', trie.search("CS101"))
print('Course code "CS301" not found →', trie.search("CS301"))
print('Prefix "CS" exists →', trie.starts_with("CS"))
print('Prefix "EE" exists →', trie.starts_with("EE"))
# Out:
# Enter number of course codes: 3
# Enter course codes:
# CS101
# CS102
# EE105
# Course code "CS101" found → True
# Course code "CS301" not found → False
# Prefix "CS" exists → True
# Prefix "EE" exists → True
